# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df=pd.read_csv('SampleSuperstore.csv')
#pd.options.display.max_rows=None
plt.style.use("seaborn-whitegrid")
import warnings
warnings.filterwarnings("ignore")
df
# Out:
# C:\Users\yusuf\AppData\Local\Temp\ipykernel_6192\1160722703.py:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# ...

# %%
print(df.shape)
print(df.dtypes)
print(df.describe())
# Out:
# (9994, 13)
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# ...

# %%
print(df.isnull().sum())
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
sns.histplot(df['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.distplot(df['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
sales_by_region = df.groupby('Region')['Sales'].sum().reset_index()
sns.barplot(x='Region', y='Sales', data=sales_by_region)
plt.show()

# %%
sales_by_ship = df.groupby('Ship Mode')['Sales'].sum().reset_index()
sns.barplot(x='Ship Mode', y='Sales', data=sales_by_ship)
plt.show()

# %%
df.Segment.value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sales_by_Segment = df.groupby('Segment')['Sales'].sum().reset_index()
sns.barplot(x='Segment', y='Sales', data=sales_by_sergent)
plt.show()

# %%
df.City.value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
df.City.nunique()
# Out:
# 531

# %%
df.State.nunique()
# Out:
# 49

# %%
plt.figure(figsize=(5,10))
sales_by_city = df.groupby('State')['Sales'].sum().reset_index()
sns.barplot(y='State', x='Sales', data=sales_by_city)
plt.show()

# %%
sales_by_sub_cat = df.groupby('Sub-Category')['Sales'].sum().reset_index()
sns.barplot(y='Sub-Category', x='Sales', data=sales_by_city)
plt.show()

# %%
sales_by_categ = df.groupby('Category')['Sales'].sum().reset_index()
sns.barplot(y='Category', x='Sales', data=sales_by_city)
plt.show()

# %%
sns.lineplot(x='Quantity',y='Sales',data=df)
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>

# %%
sns.lineplot(x='Discount',y='Sales',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Sales'>

# %%
sns.lineplot(x='Profit',y='Sales',data=df)
# Out:
# <Axes: xlabel='Profit', ylabel='Sales'>
